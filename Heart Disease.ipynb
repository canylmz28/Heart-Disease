# %% [markdown]
# # 1) Load Library And Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("fivethirtyeight")
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("heart.csv")

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# # 2) Variable Analysis

# %% [markdown]
# ### Age

# %%
plt.figure(figsize = (15,5))
sns.countplot(x = "age", data = data, order = data['age'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
plt.figure(figsize = (15,5))
sns.countplot(x = "age", data = data, hue = "target")
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %% [markdown]
# ### Sex

# %%
plt.figure(figsize = (15,5))
plt.subplot(1, 2, 1)
plt.pie(x = data["sex"].value_counts(), labels = data["sex"].value_counts().index, autopct="%.1f%%", pctdistance =0.7)
plt.subplot(1, 2, 2)
sns.countplot(x = "sex", data = data, hue = "target")
plt.suptitle("Sex (1 = male; 0 = female)")
# Out:
# Text(0.5, 0.98, 'Sex (1 = male; 0 = female)')

# %% [markdown]
# ### Chest pain type(cp)

# %%
plt.figure(figsize = (15,5))
plt.subplot(1, 2, 1)
plt.pie(x = data["cp"].value_counts(), labels = data["cp"].value_counts().index, autopct="%.1f%%", pctdistance =0.7)
plt.subplot(1, 2, 2)
sns.countplot(x = "cp", data = data, hue = "target")
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %% [markdown]
# ### Resting blood pressure(trestbps)

# %%
sns.jointplot(x = "trestbps", y = "target", data = data, kind = "reg")

# %%
sns.distplot(data["trestbps"], kde = False)
# Out:
# <AxesSubplot:xlabel='trestbps'>

# %% [markdown]
# ### Serum cholestoral(chol)

# %%
sns.distplot(data["chol"], kde = False)
# Out:
# <AxesSubplot:xlabel='chol'>

# %%
sns.jointplot(x = "chol", y = "target", data = data, kind = "reg")

# %% [markdown]
# ### Fasting blood sugar > 120 mg/dl(fbs)

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
plt.pie(x = data["fbs"].value_counts(), labels = data["fbs"].value_counts().index, autopct="%.1f%%", pctdistance =0.7)
plt.subplot(1,2,2)
sns.countplot(x = "fbs", data = data, hue = "target")
# Out:
# <AxesSubplot:xlabel='fbs', ylabel='count'>

# %% [markdown]
# ### Resting electrocardiographic results(restecg)

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
plt.pie(x = data["restecg"].value_counts(), labels = data["restecg"].value_counts().index, autopct="%.1f%%", pctdistance =0.7)
plt.subplot(1,2,2)
sns.countplot(x = "restecg", data = data, hue = "target")
# Out:
# <AxesSubplot:xlabel='restecg', ylabel='count'>

# %% [markdown]
# ### Maximum heart rate achieved(thalach)

# %%
sns.jointplot(x = "thalach", y = "target", data = data, kind = "reg")

# %% [markdown]
# ### Exercise induced angina(exang)

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
plt.pie(x = data["exang"].value_counts(), labels = data["exang"].value_counts().index, autopct="%.1f%%", pctdistance =0.7)
plt.subplot(1,2,2)
sns.countplot(x = "exang", data = data, hue = "target")
# Out:
# <AxesSubplot:xlabel='exang', ylabel='count'>

# %% [markdown]
# ### ST depression induced by exercise relative to rest(oldpeak)

# %%
sns.jointplot(x = "oldpeak", y = "target", data = data, kind = "reg")

# %% [markdown]
# ### The slope of the peak exercise ST segment(slope)

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
plt.pie(x = data["slope"].value_counts(), labels = data["slope"].value_counts().index, autopct="%.1f%%", pctdistance =0.7)
plt.subplot(1,2,2)
sns.countplot(x = "slope", data = data, hue = "target")
# Out:
# <AxesSubplot:xlabel='slope', ylabel='count'>

# %% [markdown]
# ### Number of major vessels colored by flourosopy(ca)

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
plt.pie(x = data["ca"].value_counts(), labels = data["ca"].value_counts().index, autopct="%.1f%%", pctdistance =0.7)
plt.subplot(1,2,2)
sns.countplot(x = "ca", data = data, hue = "target")
# Out:
# <AxesSubplot:xlabel='ca', ylabel='count'>

# %% [markdown]
# ### Thal

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
plt.pie(x = data["thal"].value_counts(), labels = data["thal"].value_counts().index, autopct="%.1f%%", pctdistance =0.7)
plt.subplot(1,2,2)
sns.countplot(x = "thal", data = data, hue = "target")
# Out:
# <AxesSubplot:xlabel='thal', ylabel='count'>

# %% [markdown]
# # 3) Missing Value

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # 4) Data Preprocessing

# %%
list_ = ["cp", "restecg", "exang", "thal", "ca", "slope"]

# %%
for i in list_:
    data[i] = data[i].astype(str)

# %%
data = pd.get_dummies(data)

# %%
data.columns
# Out:
# Index(['age', 'sex', 'trestbps', 'chol', 'fbs', 'thalach', 'oldpeak', 'target',
#        'cp_0', 'cp_1', 'cp_2', 'cp_3', 'restecg_0', 'restecg_1', 'restecg_2',
#        'exang_0', 'exang_1', 'slope_0', 'slope_1', 'slope_2', 'ca_0', 'ca_1',
#        'ca_2', 'ca_3', 'ca_4', 'thal_0', 'thal_1', 'thal_2', 'thal_3'],
#       dtype='object')

# %% [markdown]
# # 5) ML Models

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier

# %%
x = data.drop(["target"], axis = 1)
y = data.target.values.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }

# %%
xgb = XGBClassifier(random_state = 42)
gr = GridSearchCV(xgb, params, scoring = "accuracy", cv = 5, n_jobs = -1,verbose = 1)
model = gr.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 405 candidates, totalling 2025 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 440 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 1440 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 2002 out of 2025 | elapsed:   19.6s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 2025 out of 2025 | elapsed:   20.0s finished

# %%
model.best_score_
# Out:
# 0.847278911564626

# %%
model.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'gamma': 0.5,
#  'max_depth': 4,
#  'min_child_weight': 5,
#  'subsample': 1.0}

# %%
y_head = model.predict(x_test)
print("Test Accuracy:", accuracy_score(y_test, y_head))
# Out:
# Test Accuracy: 0.8852459016393442

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_head)

# %%
sns.heatmap(cm, annot = True)
# Out:
# <AxesSubplot:>
